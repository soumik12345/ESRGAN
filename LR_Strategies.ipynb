# %%
import tensorflow as tf
import matplotlib as mpl
from matplotlib import pyplot as plt
from matplotlib import ticker as mtick
from src.learning_rate_schedulers import *

# %% [markdown]
# ## PSNR Pre-train

# %%
lr_scheduler = MultiStepLR(2e-4, [200000, 400000, 600000, 800000], 0.5)

# %%
N_iter = 1000000
step_list = list(range(0, N_iter, 1000))
lr_list = []
for i in step_list:
    current_lr = lr_scheduler(i).numpy()
    lr_list.append(current_lr)

# %%
plt.figure(1)
plt.subplot(111)
plt.ticklabel_format(style='sci', axis='x', scilimits=(0, 0))
plt.title('PSNR Pre-Train', fontsize=16, color='k')
plt.plot(step_list, lr_list, linewidth=1.5, label='learning rate scheme')
legend = plt.legend(loc='upper right', shadow=False)
ax = plt.gca()
labels = ax.get_xticks().tolist()
for k, v in enumerate(labels):
    labels[k] = str(int(v / 1000)) + 'K'
ax.set_xticklabels(labels)
ax.yaxis.set_major_formatter(mtick.FormatStrFormatter('%.1e'))

ax.set_ylabel('Learning rate')
ax.set_xlabel('Iteration')
fig = plt.gcf()
plt.show()

# %% [markdown]
# ## ESRGAN Train

# %%
lr_scheduler = MultiStepLR(1e-4, [50000, 100000, 200000, 300000], 0.5)

# %%
N_iter = 1000000
step_list = list(range(0, N_iter, 1000))
lr_list = []
for i in step_list:
    current_lr = lr_scheduler(i).numpy()
    lr_list.append(current_lr)

# %%
plt.figure(1)
plt.subplot(111)
plt.ticklabel_format(style='sci', axis='x', scilimits=(0, 0))
plt.title('PSNR Pre-Train', fontsize=16, color='k')
plt.plot(step_list, lr_list, linewidth=1.5, label='learning rate scheme')
legend = plt.legend(loc='upper right', shadow=False)
ax = plt.gca()
labels = ax.get_xticks().tolist()
for k, v in enumerate(labels):
    labels[k] = str(int(v / 1000)) + 'K'
ax.set_xticklabels(labels)
ax.yaxis.set_major_formatter(mtick.FormatStrFormatter('%.1e'))

ax.set_ylabel('Learning rate')
ax.set_xlabel('Iteration')
fig = plt.gcf()
plt.show()

# %% [markdown]
# ## Cosine Annealing LR Scheduler

# %%
lr_scheduler = CosineAnnealingLRRestart(2e-4, 250000, 1e-7)

# %%
N_iter = 1000000
step_list = list(range(0, N_iter, 1000))
lr_list = []
for i in step_list:
    current_lr = lr_scheduler(i).numpy()
    lr_list.append(current_lr)

# %%
plt.figure(1)
plt.subplot(111)
plt.ticklabel_format(style='sci', axis='x', scilimits=(0, 0))
plt.title('PSNR Pre-Train', fontsize=16, color='k')
plt.plot(step_list, lr_list, linewidth=1.5, label='learning rate scheme')
legend = plt.legend(loc='upper right', shadow=False)
ax = plt.gca()
labels = ax.get_xticks().tolist()
for k, v in enumerate(labels):
    labels[k] = str(int(v / 1000)) + 'K'
ax.set_xticklabels(labels)
ax.yaxis.set_major_formatter(mtick.FormatStrFormatter('%.1e'))

ax.set_ylabel('Learning rate')
ax.set_xlabel('Iteration')
fig = plt.gcf()
plt.show()
